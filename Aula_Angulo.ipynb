# %% [markdown]
# <a href="https://colab.research.google.com/github/caiomansera/Teste-Aula-1/blob/main/Aula_Angulo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
import math

# cabeçalho da tabela

print(f"{'Angulo (graus)':<15} {'seno':<10}")

#Gera os valores dos angulos de 0 a 360 com intervalos de 5
for angulo in range (0, 361, 5):

#Converte o angulo de graus para radianos
  radianos = math.radians(angulo)

#Calcula o seno do angulo
  seno = math.sin(radianos)

# Exibeo angulo e seu seno correspondente
  print(f"{angulo<15} {seno:<10.4f}")
# Out:
# Angulo (graus)  seno
# True 0.0000
# True 0.0872
# True 0.1736
# False 0.2588
# False 0.3420
# False 0.4226
# False 0.5000
# False 0.5736
# False 0.6428
# False 0.7071
# False 0.7660
# False 0.8192
# False 0.8660
# False 0.9063
# False 0.9397
# False 0.9659
# False 0.9848
# False 0.9962
# False 1.0000
# False 0.9962
# False 0.9848
# False 0.9659
# False 0.9397
# False 0.9063
# False 0.8660
# False 0.8192
# False 0.7660
# False 0.7071
# False 0.6428
# False 0.5736
# False 0.5000
# False 0.4226
# False 0.3420
# False 0.2588
# False 0.1736
# False 0.0872
# False 0.0000
# False -0.0872
# False -0.1736
# False -0.2588
# False -0.3420
# False -0.4226
# False -0.5000
# False -0.5736
# False -0.6428
# False -0.7071
# False -0.7660
# False -0.8192
# False -0.8660
# False -0.9063
# False -0.9397
# False -0.9659
# False -0.9848
# False -0.9962
# False -1.0000
# False -0.9962
# False -0.9848
# False -0.9659
# False -0.9397
# False -0.9063
# False -0.8660
# False -0.8192
# False -0.7660
# ...

# %%
n = int(input("Digite a quantidade de alunos: "))

for i in range (1,n +1):
  print(f"\nAluno {i}:")
  n1 = float(input("Digite a nota N1: "))
  n2 = float(input("Digite a nota N2: "))

MEDIA = (n1+n2) / 2
print(MEDIA)
# Out:
# Digite a quantidade de alunos: 2
#
# Aluno 1:
# Digite a nota N1: 1
# Digite a nota N2: 2
#
# Aluno 2:
# Digite a nota N1: 2
# Digite a nota N2: 2
# 2.0

# %%
resp = input("Deseja Calcular? (sim, nao): ")
while resp == "sim":
  v1 = int(input("Digite o primeiro valor: "))
  v2 = int(input("Digite o segundo valor: "))
  m = (v1 + v2)/2
  print(m)
  resp = input("Deseja Calcular? (sim, nao): ")
if resp == "nao":
  print("Fim")
# Out:
# Deseja Calcular? (sim, nao): nao
# Fim
