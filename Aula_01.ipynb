# %% [markdown]
# <a href="https://colab.research.google.com/github/caiomansera/Teste-Aula-1/blob/main/Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Código Exemplo

Fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
Celsius = (5/9) * ((Fahrenheit-32))
print("A temperatura em Celsius é", Celsius, "graus")
# Out:
# Digite a temperatura em Fahrenheit: 72
# A temperatura em Celsius é 22.22222222222222 graus
